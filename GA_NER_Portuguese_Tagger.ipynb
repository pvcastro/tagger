# %%
import numpy as np
import pandas as pd
import random
import time

from deap import base, creator, tools, algorithms
from scipy.stats import bernoulli
from bitstring import BitArray

import parameters
import ner
import sentence_tagger

# %%
def replace(individual, indexes, value):
    binary_format = '{0:0' + str(indexes[1] - indexes[0])  + 'b}'
    binary_value = binary_format.format(value)
    index_list = list(range(*indexes))
    assert len(index_list) == len(binary_value), 'Binary representation must be the same size as the indexes interval'
    for (index, replacement) in zip(index_list, binary_value):
        individual[index] = int(replacement)

# %%
def check_and_replace_if_needed(individual, indexes, min_value, max_value):
    value_bits = BitArray(individual[slice(*indexes)])
    int_value = value_bits.uint
    if int_value < min_value:
        print('adjusting individual to lower bound, switching', int_value, 'at position', indexes, 'for', min_value)
        replace(indexes=indexes, individual=individual, value=min_value)
    elif int_value > max_value:
        print('adjusting individual to upper bound, switching', int_value, 'at position', indexes, 'for', max_value)
        replace(indexes=indexes, individual=individual, value=max_value)

# %%
def adjust_individual(individual, min_char_lstm_dim=10, max_char_lstm_dim=50, min_word_lstm_dim=50, max_word_lstm_dim=200):
    check_and_replace_if_needed(individual=individual, 
                                indexes=(2,8), 
                                min_value=min_char_lstm_dim, 
                                max_value=max_char_lstm_dim)
    check_and_replace_if_needed(individual=individual, 
                                indexes=(9,17), 
                                min_value=min_word_lstm_dim, 
                                max_value=max_word_lstm_dim)

# %%
def check_individual():
    def decorator(func):
        def wrapper(*args, **kargs):
            individual = func(*args, **kargs)
            adjust_individual(individual=individual)
            return individual
        return wrapper
    return decorator

# %%
def check_mate():
    def decorator(func):
        def wrapper(*args, **kargs):
            children = func(*args, **kargs)
            child1, child2 = children
            adjust_individual(child1)
            adjust_individual(child2)
            return children
        return wrapper
    return decorator

# %%
def check_mutation():
    def decorator(func):
        def wrapper(*args, **kargs):
            mutant = func(*args, **kargs)
            adjust_individual(mutant[0])
            return mutant
        return wrapper
    return decorator

# %%
def train_evaluate(ga_individual_solution):
    training_parameters = parameters.get_parameters_from_individual(ga_individual_solution=ga_individual_solution, 
                                                                    train='dataset/train.txt', 
                                                                    dev='dataset/dev.txt', 
                                                                    test='dataset/test.txt', 
                                                                    tag_scheme='iob', 
                                                                    char_dim=25, 
                                                                    word_dim=100, 
                                                                    pre_emb='embeddings/glove_s100.txt', 
                                                                    all_emb=True, 
                                                                    crf=True, 
                                                                    dropout=0.5, 
                                                                    lr_method='sgd-lr_.005',
                                                                    reload=False)
    print('Lower text?', training_parameters['lower'], 
          'Replace digits with zero?', training_parameters['zeros'], 
          'Dimension of LSTM for chars:', training_parameters['char_lstm_dim'],
          'Use bidirectional LSTM for chars?', training_parameters['char_bidirect'],
          'Dimension of LSTM for words:', training_parameters['word_lstm_dim'],
          'Use bidirectional LSTM for words?', training_parameters['word_bidirect'],
          'Dimension of capitalization features:', training_parameters['cap_dim'])
    model = ner.NER(parameters=training_parameters)
    f1_score = model.train(n_epochs=5, verbose=False)
    return f1_score,

# %%
population_size = 4
num_generations = 4
gene_length = 19

# %%
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
toolbox.register('binary', bernoulli.rvs, 0.5)
toolbox.register('individual', tools.initRepeat, creator.Individual, toolbox.binary, n = gene_length)
toolbox.decorate('individual', check_individual())
toolbox.register('population', tools.initRepeat, list , toolbox.individual)

toolbox.register('mate', tools.cxOrdered)
toolbox.decorate('mate', check_mate())
toolbox.register('mutate', tools.mutShuffleIndexes, indpb = 0.6)
toolbox.decorate('mutate', check_mutation())
toolbox.register('select', tools.selTournament, tournsize=2)
toolbox.register('evaluate', train_evaluate)

# %%
population = toolbox.population(n = population_size)
r = algorithms.eaSimple(population, toolbox, cxpb = 0.4, mutpb = 0.1, ngen = num_generations, verbose = False)
print(time.ctime())
# Out:
# ('adjusting individual to lower bound, switching', 0, 'at position', (9, 17), 'for', 50)
# ('adjusting individual to upper bound, switching', 255, 'at position', (9, 17), 'for', 200)
# ('Lower text?', False, 'Replace digits with zero?', True, 'Dimension of LSTM for chars:', 37, 'Use bidirectional LSTM for chars?', False, 'Dimension of LSTM for words:', 50, 'Use bidirectional LSTM for words?', False, 'Dimension of capitalization features:', 0)
# Model location: ./models/tag_scheme=iob,lower=False,zeros=True,char_dim=25,char_lstm_dim=37,char_bidirect=False,word_dim=100,word_lstm_dim=50,word_bidirect=False,pre_emb=glove_s100.txt,all_emb=True,cap_dim=0,crf=True,dropout=0.5,lr_method=sgd-lr_.005
# Found 13639 unique words (62480 in total)
# Loading pretrained embeddings from embeddings/glove_s100.txt...
# Found 114 unique characters
# Found 21 unique named entity tags
# 2955 / 529 / 854 sentences in train / dev / test.
# Saving the mappings to disk...
# Loading pretrained embeddings from embeddings/glove_s100.txt...
# WARNING: 2349 invalid lines
# Loaded 931381 pretrained embeddings.
# 935019 / 936050 (99.8899%) words have been initialized with pretrained embeddings.
# 931381 found directly, 3631 after lowercasing, 7 after lowercasing + zero.
# Compiling...
# ('Starting epoch 0 at...', 'Fri Jan 26 09:36:28 2018')
# processed 8831 tokens with 709 phrases; found: 1 phrases; correct: 1.
# accuracy:  84.60%; precision: 100.00%; recall:   0.14%; FB1:   0.28
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision: 100.00%; recall:   0.48%; FB1:   0.96  1
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7471/8831 (84.59971%)
# Score on dev: 0.28000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 31 phrases; correct: 8.
# accuracy:  84.74%; precision:  25.81%; recall:   1.13%; FB1:   2.16
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:   0.00%; recall:   0.00%; FB1:   0.00  2
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  29.63%; recall:   3.85%; FB1:   6.81  27
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  2
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7483/8831 (84.73559%)
# Score on dev: 2.16000
# New best score on dev.
# Saving model to disk...
# Epoch 0 done. Average cost: 14.646992
# ('Starting epoch 1 at...', 'Fri Jan 26 09:37:36 2018')
# processed 8831 tokens with 709 phrases; found: 70 phrases; correct: 33.
# accuracy:  85.21%; precision:  47.14%; recall:   4.65%; FB1:   8.47
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  44.44%; recall:   8.70%; FB1:  14.55  27
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  48.65%; recall:   8.65%; FB1:  14.69  37
#             TEMPO: precision:  50.00%; recall:   2.46%; FB1:   4.69  6
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7525/8831 (85.21119%)
# Score on dev: 8.47000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 229 phrases; correct: 106.
# accuracy:  86.47%; precision:  46.29%; recall:  14.95%; FB1:  22.60
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  37.21%; recall:  23.19%; FB1:  28.57  86
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  47.56%; recall:  79.81%; FB1:  59.61  349
#             TEMPO: precision:  61.36%; recall:  44.26%; FB1:  51.43  88
#             VALOR: precision:  46.15%; recall:  29.27%; FB1:  35.82  26
# 8021/8831 (90.82777%)
# Score on dev: 49.10000
# New best score on dev.
# Saving model to disk...
# Epoch 4 done. Average cost: 4.518903
# ('Lower text?', True, 'Replace digits with zero?', True, 'Dimension of LSTM for chars:', 34, 'Use bidirectional LSTM for chars?', True, 'Dimension of LSTM for words:', 200, 'Use bidirectional LSTM for words?', True, 'Dimension of capitalization features:', 1)
# Model location: ./models/tag_scheme=iob,lower=True,zeros=True,char_dim=25,char_lstm_dim=34,char_bidirect=True,word_dim=100,word_lstm_dim=200,word_bidirect=True,pre_emb=glove_s100.txt,all_emb=True,cap_dim=1,crf=True,dropout=0.5,lr_method=sgd-lr_.005
# Found 12383 unique words (62480 in total)
# Loading pretrained embeddings from embeddings/glove_s100.txt...
# Found 114 unique characters
# Found 21 unique named entity tags
# 2955 / 529 / 854 sentences in train / dev / test.
# Saving the mappings to disk...
# Loading pretrained embeddings from embeddings/glove_s100.txt...
# WARNING: 2349 invalid lines
# Loaded 931381 pretrained embeddings.
# 931389 / 932409 (99.8906%) words have been initialized with pretrained embeddings.
# 931381 found directly, 1 after lowercasing, 7 after lowercasing + zero.
# Compiling...
# ('Starting epoch 0 at...', 'Fri Jan 26 09:43:43 2018')
# processed 8831 tokens with 709 phrases; found: 237 phrases; correct: 113.
# accuracy:  86.76%; precision:  47.68%; recall:  15.94%; FB1:  23.89
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  67.74%; recall:  15.22%; FB1:  24.85  31
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  44.88%; recall:  44.23%; FB1:  44.55  205
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  1
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7662/8831 (86.76254%)
# Score on dev: 23.89000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 420 phrases; correct: 205.
# accuracy:  88.12%; precision:  48.81%; recall:  28.91%; FB1:  36.32
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  42.26%; recall:  51.45%; FB1:  46.41  168
#              OBRA: precision:  50.00%; recall:   1.92%; FB1:   3.70  2
#       ORGANIZACAO: precision:  25.00%; recall:   5.00%; FB1:   8.33  8
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  64.60%; recall:  50.00%; FB1:  56.37  161
#             TEMPO: precision:  33.33%; recall:  22.13%; FB1:  26.60  81
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7782/8831 (88.12139%)
# Score on dev: 36.32000
# New best score on dev.
# Saving model to disk...
# Epoch 0 done. Average cost: 12.230147
# ('Starting epoch 1 at...', 'Fri Jan 26 09:45:18 2018')
# processed 8831 tokens with 709 phrases; found: 466 phrases; correct: 257.
# accuracy:  89.48%; precision:  55.15%; recall:  36.25%; FB1:  43.74
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  53.24%; recall:  53.62%; FB1:  53.43  139
#              OBRA: precision:  33.33%; recall:   1.92%; FB1:   3.64  3
#       ORGANIZACAO: precision:  77.78%; recall:  17.50%; FB1:  28.57  9
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  56.05%; recall:  66.83%; FB1:  60.96  248
#             TEMPO: precision:  52.31%; recall:  27.87%; FB1:  36.36  65
#             VALOR: precision: 100.00%; recall:   4.88%; FB1:   9.30  2
# 7902/8831 (89.48024%)
# Score on dev: 43.74000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 581 phrases; correct: 320.
# accuracy:  90.59%; precision:  55.08%; recall:  45.13%; FB1:  49.61
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  79.70%; recall:  75.48%; FB1:  77.53  197
#             TEMPO: precision:  67.03%; recall:  50.00%; FB1:  57.28  91
#             VALOR: precision:  74.19%; recall:  56.10%; FB1:  63.89  31
# 8209/8831 (92.95663%)
# Score on dev: 59.90000
# New best score on dev.
# Saving model to disk...
# Epoch 3 done. Average cost: 4.431551
# ('Starting epoch 4 at...', 'Fri Jan 26 09:50:14 2018')
# processed 8831 tokens with 709 phrases; found: 680 phrases; correct: 411.
# accuracy:  92.18%; precision:  60.44%; recall:  57.97%; FB1:  59.18
#        ABSTRACCAO: precision:  51.85%; recall:  34.15%; FB1:  41.18  27
#     ACONTECIMENTO: precision:  75.00%; recall:  24.00%; FB1:  36.36  8
#             COISA: precision:  52.00%; recall:  35.14%; FB1:  41.94  25
#             LOCAL: precision:  63.10%; recall:  76.81%; FB1:  69.28  168
#              OBRA: precision:  28.57%; recall:   7.69%; FB1:  12.12  14
#       ORGANIZACAO: precision:  29.63%; recall:  60.00%; FB1:  39.67  81
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  78.82%; recall:  76.92%; FB1:  77.86  203
#             TEMPO: precision:  50.39%; recall:  52.46%; FB1:  51.41  127
#             VALOR: precision:  74.07%; recall:  48.78%; FB1:  58.82  27
# 8140/8831 (92.17529%)
# Score on dev: 59.18000
# processed 8831 tokens with 709 phrases; found: 690 phrases; correct: 422.
# accuracy:  92.12%; precision:  61.16%; recall:  59.52%; FB1:  60.33
#        ABSTRACCAO: precision:  44.00%; recall:  26.83%; FB1:  33.33  25
#     ACONTECIMENTO: precision: 100.00%; recall:  28.00%; FB1:  43.75  7
#             COISA: precision:  36.84%; recall:  37.84%; FB1:  37.33  38
#             LOCAL: precision:  61.62%; recall:  82.61%; FB1:  70.59  185
#              OBRA: precision:  19.15%; recall:  17.31%; FB1:  18.18  47
#       ORGANIZACAO: precision:  64.71%; recall:  27.50%; FB1:  38.60  17
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  72.61%; recall:  80.29%; FB1:  76.26  230
#             TEMPO: precision:  64.65%; recall:  52.46%; FB1:  57.92  99
#             VALOR: precision:  59.52%; recall:  60.98%; FB1:  60.24  42
# 8135/8831 (92.11867%)
# Score on dev: 60.33000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 660 phrases; correct: 408.
# accuracy:  92.96%; precision:  61.82%; recall:  57.55%; FB1:  59.61
#        ABSTRACCAO: precision:  30.38%; recall:  58.54%; FB1:  40.00  79
#     ACONTECIMENTO: precision:  87.50%; recall:  28.00%; FB1:  42.42  8
#             COISA: precision:  36.84%; recall:  18.92%; FB1:  25.00  19
#             LOCAL: precision:  66.20%; recall:  68.12%; FB1:  67.14  142
#              OBRA: precision:  31.25%; recall:   9.62%; FB1:  14.71  16
#       ORGANIZACAO: precision:  29.47%; recall:  70.00%; FB1:  41.48  95
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  80.51%; recall:  75.48%; FB1:  77.92  195
#             TEMPO: precision:  83.10%; recall:  48.36%; FB1:  61.14  71
#             VALOR: precision:  77.14%; recall:  65.85%; FB1:  71.05  35
# 8209/8831 (92.95663%)
# Score on dev: 59.61000
# Epoch 4 done. Average cost: 3.989693
# ('Lower text?', True, 'Replace digits with zero?', False, 'Dimension of LSTM for chars:', 15, 'Use bidirectional LSTM for chars?', True, 'Dimension of LSTM for words:', 144, 'Use bidirectional LSTM for words?', False, 'Dimension of capitalization features:', 0)
# Model location: ./models/tag_scheme=iob,lower=True,zeros=False,char_dim=25,char_lstm_dim=15,char_bidirect=True,word_dim=100,word_lstm_dim=144,word_bidirect=False,pre_emb=glove_s100.txt,all_emb=True,cap_dim=0,crf=True,dropout=0.5,lr_method=sgd-lr_.005
# Found 12769 unique words (62480 in total)
# Loading pretrained embeddings from embeddings/glove_s100.txt...
# Found 123 unique characters
# Found 21 unique named entity tags
# 2955 / 529 / 854 sentences in train / dev / test.
# Saving the mappings to disk...
# Loading pretrained embeddings from embeddings/glove_s100.txt...
# WARNING: 2349 invalid lines
# Loaded 931381 pretrained embeddings.
# 931866 / 932886 (99.8907%) words have been initialized with pretrained embeddings.
# 931381 found directly, 1 after lowercasing, 484 after lowercasing + zero.
# Compiling...
# ('Starting epoch 0 at...', 'Fri Jan 26 09:53:22 2018')
# processed 8831 tokens with 709 phrases; found: 0 phrases; correct: 0.
# accuracy:  84.58%; precision:   0.00%; recall:   0.00%; FB1:   0.00
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7469/8831 (84.57706%)
# Score on dev: 0.00000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 49 phrases; correct: 22.
# accuracy:  85.15%; precision:  44.90%; recall:   3.10%; FB1:   5.80
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  44.90%; recall:  10.58%; FB1:  17.12  49
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7520/8831 (85.15457%)
# Score on dev: 5.80000
# New best score on dev.
# Saving model to disk...
# Epoch 0 done. Average cost: 14.592056
# ('Starting epoch 1 at...', 'Fri Jan 26 09:54:49 2018')
# processed 8831 tokens with 709 phrases; found: 156 phrases; correct: 83.
# accuracy:  86.12%; precision:  53.21%; recall:  11.71%; FB1:  19.19
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  50.94%; recall:  19.57%; FB1:  28.27  53
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  54.90%; recall:  26.92%; FB1:  36.13  102
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  1
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7605/8831 (86.11709%)
# Score on dev: 19.19000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 222 phrases; correct: 129.
# accuracy:  86.91%; precision:  58.11%; recall:  18.19%; FB1:  27.71
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  53.85%; recall:  35.51%; FB1:  42.79  91
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  62.02%; recall:  38.46%; FB1:  47.48  129
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  2
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7675/8831 (86.90975%)
# Score on dev: 27.71000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 465 phrases; correct: 234.
# accuracy:  88.76%; precision:  50.32%; recall:  33.00%; FB1:  39.86
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  39.13%; recall:  65.22%; FB1:  48.91  230
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  4
#       ORGANIZACAO: precision:  36.67%; recall:  27.50%; FB1:  31.43  30
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  66.86%; recall:  55.29%; FB1:  60.53  172
#             TEMPO: precision:  62.07%; recall:  14.75%; FB1:  23.84  29
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7838/8831 (88.75552%)
# Score on dev: 39.86000
# New best score on dev.
# Saving model to disk...
# Epoch 1 done. Average cost: 8.785760
# ('Starting epoch 2 at...', 'Fri Jan 26 09:56:15 2018')
# processed 8831 tokens with 709 phrases; found: 566 phrases; correct: 290.
# accuracy:  89.68%; precision:  51.24%; recall:  40.90%; FB1:  45.49
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  40.55%; recall:  74.64%; FB1:  52.55  254
#              OBRA: precision:  16.67%; recall:   1.92%; FB1:   3.45  6
#       ORGANIZACAO: precision:  29.31%; recall:  42.50%; FB1:  34.69  58
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  66.22%; recall:  70.67%; FB1:  68.37  222
#             TEMPO: precision:  84.62%; recall:  18.03%; FB1:  29.73  26
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7920/8831 (89.68407%)
# Score on dev: 45.49000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 569 phrases; correct: 292.
# accuracy:  89.80%; precision:  51.32%; recall:  41.18%; FB1:  45.70
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  50.26%; recall:  71.01%; FB1:  58.86  195
#              OBRA: precision:   3.70%; recall:   1.92%; FB1:   2.53  27
#       ORGANIZACAO: precision:  25.29%; recall:  55.00%; FB1:  34.65  87
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  63.36%; recall:  70.67%; FB1:  66.82  232
#             TEMPO: precision:  85.71%; recall:  19.67%; FB1:  32.00  28
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7930/8831 (89.79730%)
# Score on dev: 45.70000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 612 phrases; correct: 326.
# accuracy:  90.53%; precision:  53.27%; recall:  45.98%; FB1:  49.36
#        ABSTRACCAO: precision: 100.00%; recall:   4.88%; FB1:   9.30  2
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:  20.00%; recall:   2.70%; FB1:   4.76  5
#             LOCAL: precision:  53.98%; recall:  68.84%; FB1:  60.51  176
#              OBRA: precision:   6.90%; recall:   3.85%; FB1:   4.94  29
#       ORGANIZACAO: precision:  31.94%; recall:  57.50%; FB1:  41.07  72
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  61.48%; recall:  75.96%; FB1:  67.96  257
#             TEMPO: precision:  80.00%; recall:  32.79%; FB1:  46.51  50
#             VALOR: precision:  23.81%; recall:  12.20%; FB1:  16.13  21
# 7995/8831 (90.53335%)
# Score on dev: 49.36000
# New best score on dev.
# Saving model to disk...
# Epoch 2 done. Average cost: 6.082853
# ('Starting epoch 3 at...', 'Fri Jan 26 09:57:41 2018')
# processed 8831 tokens with 709 phrases; found: 589 phrases; correct: 330.
# accuracy:  90.70%; precision:  56.03%; recall:  46.54%; FB1:  50.85
#        ABSTRACCAO: precision: 100.00%; recall:   2.44%; FB1:   4.76  1
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision: 100.00%; recall:   2.70%; FB1:   5.26  1
#             LOCAL: precision:  60.26%; recall:  68.12%; FB1:  63.95  156
#              OBRA: precision:  11.11%; recall:   3.85%; FB1:   5.71  18
#       ORGANIZACAO: precision:  25.00%; recall:  62.50%; FB1:  35.71  100
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  64.29%; recall:  77.88%; FB1:  70.43  252
#             TEMPO: precision:  77.78%; recall:  34.43%; FB1:  47.73  54
#             VALOR: precision:  42.86%; recall:   7.32%; FB1:  12.50  7
# 8010/8831 (90.70320%)
# Score on dev: 50.85000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 572 phrases; correct: 336.
# accuracy:  91.03%; precision:  58.74%; recall:  47.39%; FB1:  52.46
#        ABSTRACCAO: precision:  35.00%; recall:  17.07%; FB1:  22.95  20
#     ACONTECIMENTO: precision: 100.00%; recall:  12.00%; FB1:  21.43  3
#             COISA: precision:  20.00%; recall:   2.70%; FB1:   4.76  5
#             LOCAL: precision:  58.02%; recall:  68.12%; FB1:  62.67  162
#              OBRA: precision:  33.33%; recall:   1.92%; FB1:   3.64  3
#       ORGANIZACAO: precision:  33.85%; recall:  55.00%; FB1:  41.90  65
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  63.71%; recall:  79.33%; FB1:  70.66  259
#             TEMPO: precision:  80.77%; recall:  34.43%; FB1:  48.28  52
#             VALOR: precision:  33.33%; recall:   2.44%; FB1:   4.55  3
# 8039/8831 (91.03159%)
# Score on dev: 52.46000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 599 phrases; correct: 332.
# accuracy:  91.07%; precision:  55.43%; recall:  46.83%; FB1:  50.76
#        ABSTRACCAO: precision:  57.14%; recall:   9.76%; FB1:  16.67  7
#     ACONTECIMENTO: precision:  37.50%; recall:  12.00%; FB1:  18.18  8
#             COISA: precision:  33.33%; recall:   2.70%; FB1:   5.00  3
#             LOCAL: precision:  62.07%; recall:  65.22%; FB1:  63.60  145
#              OBRA: precision:   7.69%; recall:   3.85%; FB1:   5.13  26
#       ORGANIZACAO: precision:  21.78%; recall:  55.00%; FB1:  31.21  101
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  80.00%; recall:  69.23%; FB1:  74.23  180
#             TEMPO: precision:  72.06%; recall:  40.16%; FB1:  51.58  68
#             VALOR: precision:  53.85%; recall:  17.07%; FB1:  25.93  13
# 8100/8831 (91.72234%)
# Score on dev: 53.89000
# New best score on dev.
# Saving model to disk...
# Epoch 4 done. Average cost: 4.496271
# ('Lower text?', True, 'Replace digits with zero?', False, 'Dimension of LSTM for chars:', 17, 'Use bidirectional LSTM for chars?', False, 'Dimension of LSTM for words:', 163, 'Use bidirectional LSTM for words?', False, 'Dimension of capitalization features:', 1)
# Model location: ./models/tag_scheme=iob,lower=True,zeros=False,char_dim=25,char_lstm_dim=17,char_bidirect=False,word_dim=100,word_lstm_dim=163,word_bidirect=False,pre_emb=glove_s100.txt,all_emb=True,cap_dim=1,crf=True,dropout=0.5,lr_method=sgd-lr_.005
# Found 12769 unique words (62480 in total)
# Loading pretrained embeddings from embeddings/glove_s100.txt...
# Found 123 unique characters
# Found 21 unique named entity tags
# 2955 / 529 / 854 sentences in train / dev / test.
# Saving the mappings to disk...
# Loading pretrained embeddings from embeddings/glove_s100.txt...
# WARNING: 2349 invalid lines
# Loaded 931381 pretrained embeddings.
# 931866 / 932886 (99.8907%) words have been initialized with pretrained embeddings.
# 931381 found directly, 1 after lowercasing, 484 after lowercasing + zero.
# Compiling...
# ('Starting epoch 0 at...', 'Fri Jan 26 10:01:54 2018')
# processed 8831 tokens with 709 phrases; found: 9 phrases; correct: 3.
# accuracy:  84.68%; precision:  33.33%; recall:   0.42%; FB1:   0.84
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  33.33%; recall:   1.44%; FB1:   2.76  9
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7478/8831 (84.67897%)
# Score on dev: 0.84000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 180 phrases; correct: 119.
# accuracy:  86.86%; precision:  66.11%; recall:  16.78%; FB1:  26.77
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  71.43%; recall:  25.36%; FB1:  37.43  49
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  64.12%; recall:  40.38%; FB1:  49.56  131
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7671/8831 (86.86445%)
# Score on dev: 26.77000
# New best score on dev.
# Saving model to disk...
# Epoch 0 done. Average cost: 13.474891
# ('Starting epoch 1 at...', 'Fri Jan 26 10:03:02 2018')
# processed 8831 tokens with 709 phrases; found: 322 phrases; correct: 191.
# accuracy:  88.20%; precision:  59.32%; recall:  26.94%; FB1:  37.05
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  59.48%; recall:  50.00%; FB1:  54.33  116
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:  42.86%; recall:  15.00%; FB1:  22.22  14
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  60.42%; recall:  55.77%; FB1:  58.00  192
# ...
#             TEMPO: precision:  76.54%; recall:  50.82%; FB1:  61.08  81
#             VALOR: precision:  81.82%; recall:  65.85%; FB1:  72.97  33
# 8257/8831 (93.50017%)
# Score on dev: 62.64000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 661 phrases; correct: 415.
# accuracy:  93.10%; precision:  62.78%; recall:  58.53%; FB1:  60.58
#        ABSTRACCAO: precision:  34.38%; recall:  26.83%; FB1:  30.14  32
#     ACONTECIMENTO: precision:  90.00%; recall:  36.00%; FB1:  51.43  10
#             COISA: precision:  42.86%; recall:  16.22%; FB1:  23.53  14
#             LOCAL: precision:  66.03%; recall:  74.64%; FB1:  70.07  156
#              OBRA: precision:  24.24%; recall:  15.38%; FB1:  18.82  33
#       ORGANIZACAO: precision:  51.52%; recall:  42.50%; FB1:  46.58  33
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  64.41%; recall:  87.02%; FB1:  74.03  281
#             TEMPO: precision:  80.56%; recall:  47.54%; FB1:  59.79  72
#             VALOR: precision:  73.33%; recall:  53.66%; FB1:  61.97  30
# 8222/8831 (93.10384%)
# Score on dev: 60.58000
# Epoch 4 done. Average cost: 3.915641
# ('Lower text?', True, 'Replace digits with zero?', False, 'Dimension of LSTM for chars:', 46, 'Use bidirectional LSTM for chars?', True, 'Dimension of LSTM for words:', 149, 'Use bidirectional LSTM for words?', False, 'Dimension of capitalization features:', 0)
# Model location: ./models/tag_scheme=iob,lower=True,zeros=False,char_dim=25,char_lstm_dim=46,char_bidirect=True,word_dim=100,word_lstm_dim=149,word_bidirect=False,pre_emb=glove_s100.txt,all_emb=True,cap_dim=0,crf=True,dropout=0.5,lr_method=sgd-lr_.005
# Found 12769 unique words (62480 in total)
# Loading pretrained embeddings from embeddings/glove_s100.txt...
# Found 123 unique characters
# Found 21 unique named entity tags
# 2955 / 529 / 854 sentences in train / dev / test.
# Saving the mappings to disk...
# Loading pretrained embeddings from embeddings/glove_s100.txt...
# WARNING: 2349 invalid lines
# Loaded 931381 pretrained embeddings.
# 931866 / 932886 (99.8907%) words have been initialized with pretrained embeddings.
# 931381 found directly, 1 after lowercasing, 484 after lowercasing + zero.
# Compiling...
# ('Starting epoch 0 at...', 'Fri Jan 26 11:25:28 2018')
# processed 8831 tokens with 709 phrases; found: 5 phrases; correct: 1.
# accuracy:  84.60%; precision:  20.00%; recall:   0.14%; FB1:   0.28
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  20.00%; recall:   0.48%; FB1:   0.94  5
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7471/8831 (84.59971%)
# Score on dev: 0.28000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 73 phrases; correct: 36.
# accuracy:  85.36%; precision:  49.32%; recall:   5.08%; FB1:   9.21
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  77.78%; recall:   5.07%; FB1:   9.52  9
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  45.31%; recall:  13.94%; FB1:  21.32  64
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7538/8831 (85.35840%)
# Score on dev: 9.21000
# New best score on dev.
# Saving model to disk...
# Epoch 0 done. Average cost: 14.567118
# ('Starting epoch 1 at...', 'Fri Jan 26 11:26:50 2018')
# processed 8831 tokens with 709 phrases; found: 179 phrases; correct: 100.
# accuracy:  86.29%; precision:  55.87%; recall:  14.10%; FB1:  22.52
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  54.69%; recall:  25.36%; FB1:  34.65  64
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  56.52%; recall:  31.25%; FB1:  40.25  115
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7620/8831 (86.28694%)
# Score on dev: 22.52000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 420 phrases; correct: 200.
# accuracy:  87.95%; precision:  47.62%; recall:  28.21%; FB1:  35.43
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  34.04%; recall:  57.97%; FB1:  42.90  235
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:  77.78%; recall:  17.50%; FB1:  28.57  9
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  66.88%; recall:  49.52%; FB1:  56.91  154
#             TEMPO: precision:  45.45%; recall:   8.20%; FB1:  13.89  22
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7767/8831 (87.95153%)
# Score on dev: 35.43000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 562 phrases; correct: 298.
# accuracy:  89.72%; precision:  53.02%; recall:  42.03%; FB1:  46.89
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  50.53%; recall:  69.57%; FB1:  58.54  190
#              OBRA: precision:   4.76%; recall:   1.92%; FB1:   2.74  21
#       ORGANIZACAO: precision:  35.85%; recall:  47.50%; FB1:  40.86  53
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  62.14%; recall:  72.60%; FB1:  66.96  243
#             TEMPO: precision:  56.36%; recall:  25.41%; FB1:  35.03  55
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7923/8831 (89.71804%)
# Score on dev: 46.89000
# New best score on dev.
# Saving model to disk...
# Epoch 1 done. Average cost: 8.260280
# ('Starting epoch 2 at...', 'Fri Jan 26 11:28:18 2018')
# processed 8831 tokens with 709 phrases; found: 601 phrases; correct: 314.
# accuracy:  90.11%; precision:  52.25%; recall:  44.29%; FB1:  47.94
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  45.00%; recall:  71.74%; FB1:  55.31  220
#              OBRA: precision:  14.29%; recall:   1.92%; FB1:   3.39  7
#       ORGANIZACAO: precision:  37.50%; recall:  45.00%; FB1:  40.91  48
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  59.52%; recall:  82.69%; FB1:  69.22  289
#             TEMPO: precision:  64.86%; recall:  19.67%; FB1:  30.19  37
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7958/8831 (90.11437%)
# Score on dev: 47.94000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 622 phrases; correct: 328.
# accuracy:  90.52%; precision:  52.73%; recall:  46.26%; FB1:  49.29
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  44.81%; recall:  78.26%; FB1:  56.99  241
#              OBRA: precision:  22.22%; recall:   3.85%; FB1:   6.56  9
#       ORGANIZACAO: precision:  32.08%; recall:  42.50%; FB1:  36.56  53
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  62.65%; recall:  77.40%; FB1:  69.25  257
#             TEMPO: precision:  64.52%; recall:  32.79%; FB1:  43.48  62
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7994/8831 (90.52202%)
# Score on dev: 49.29000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 621 phrases; correct: 313.
# accuracy:  90.68%; precision:  50.40%; recall:  44.15%; FB1:  47.07
#        ABSTRACCAO: precision:  28.57%; recall:   4.88%; FB1:   8.33  7
#     ACONTECIMENTO: precision: 100.00%; recall:   4.00%; FB1:   7.69  1
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  55.26%; recall:  60.87%; FB1:  57.93  152
#              OBRA: precision:   8.70%; recall:   3.85%; FB1:   5.33  23
#       ORGANIZACAO: precision:  16.13%; recall:  62.50%; FB1:  25.64  155
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  68.95%; recall:  72.60%; FB1:  70.73  219
#             TEMPO: precision:  78.85%; recall:  33.61%; FB1:  47.13  52
#             VALOR: precision:  58.33%; recall:  17.07%; FB1:  26.42  12
# 8008/8831 (90.68056%)
# Score on dev: 47.07000
# Epoch 2 done. Average cost: 5.700254
# ('Starting epoch 3 at...', 'Fri Jan 26 11:29:41 2018')
# processed 8831 tokens with 709 phrases; found: 598 phrases; correct: 328.
# accuracy:  90.94%; precision:  54.85%; recall:  46.26%; FB1:  50.19
#        ABSTRACCAO: precision:  33.33%; recall:   2.44%; FB1:   4.55  3
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  53.59%; recall:  70.29%; FB1:  60.82  181
#              OBRA: precision:   5.56%; recall:   1.92%; FB1:   2.86  18
#       ORGANIZACAO: precision:  50.00%; recall:  42.50%; FB1:  45.95  34
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  55.52%; recall:  82.21%; FB1:  66.28  308
#             TEMPO: precision:  75.00%; recall:  31.97%; FB1:  44.83  52
#             VALOR: precision: 100.00%; recall:   4.88%; FB1:   9.30  2
# 8031/8831 (90.94100%)
# Score on dev: 50.19000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 635 phrases; correct: 349.
# accuracy:  91.12%; precision:  54.96%; recall:  49.22%; FB1:  51.93
#        ABSTRACCAO: precision:  12.50%; recall:   2.44%; FB1:   4.08  8
#     ACONTECIMENTO: precision: 100.00%; recall:   4.00%; FB1:   7.69  1
#             COISA: precision:  36.84%; recall:  18.92%; FB1:  25.00  19
#             LOCAL: precision:  61.39%; recall:  70.29%; FB1:  65.54  158
#              OBRA: precision:   8.33%; recall:   1.92%; FB1:   3.12  12
#       ORGANIZACAO: precision:  32.14%; recall:  45.00%; FB1:  37.50  56
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:

# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 628 phrases; correct: 387.
# accuracy:  92.36%; precision:  61.62%; recall:  54.58%; FB1:  57.89
#        ABSTRACCAO: precision:  47.37%; recall:  21.95%; FB1:  30.00  19
#     ACONTECIMENTO: precision:  60.00%; recall:  12.00%; FB1:  20.00  5
#             COISA: precision:  34.29%; recall:  32.43%; FB1:  33.33  35
#             LOCAL: precision:  65.16%; recall:  73.19%; FB1:  68.94  155
#              OBRA: precision:  20.83%; recall:   9.62%; FB1:  13.16  24
#       ORGANIZACAO: precision:  46.67%; recall:  52.50%; FB1:  49.41  45
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  66.79%; recall:  84.13%; FB1:  74.47  262
#             TEMPO: precision:  76.56%; recall:  40.16%; FB1:  52.69  64
#             VALOR: precision:  63.16%; recall:  29.27%; FB1:  40.00  19
# 8156/8831 (92.35647%)
# Score on dev: 57.89000
# New best score on dev.
# Saving model to disk...
# Epoch 4 done. Average cost: 4.331586
# Fri Jan 26 11:32:27 2018

# %%
best_individuals = tools.selBest(population,k = 1)

lower = None
zeros = None
char_lstm_dim = None
char_bidirect = None
word_lstm_dim = None
word_bidirect = None
cap_dim = None

for bi in best_individuals:
    lower_bit = bi[0]
    zeros_bit = bi[1]
    char_lstm_dim_bits = BitArray(bi[2:8])
    char_bidirect_bit = bi[8]
    word_lstm_dim_bits = BitArray(bi[9:17])
    word_bidirect_bit = bi[17]
    cap_dim_bit = bi[18]
    
    lower = lower_bit == 1
    zeros = zeros_bit == 1
    char_lstm_dim = char_lstm_dim_bits.uint
    char_bidirect = char_bidirect_bit == 1
    word_lstm_dim = word_lstm_dim_bits.uint
    word_bidirect = word_bidirect_bit == 1
    cap_dim = cap_dim_bit
    
    print('Lower text?', lower, 
          'Replace digits with zero?', zeros, 
          'Dimension of LSTM for chars:', char_lstm_dim,
          'Use bidirectional LSTM for chars?', char_bidirect,
          'Dimension of LSTM for words:', word_lstm_dim,
          'Use bidirectional LSTM for words?', word_bidirect,
          'Dimension of capitalization features:', cap_dim,
          'F1 score:', bi.fitness.values)
# Out:
# ('Lower text?', True, 'Replace digits with zero?', True, 'Dimension of LSTM for chars:', 34, 'Use bidirectional LSTM for chars?', True, 'Dimension of LSTM for words:', 200, 'Use bidirectional LSTM for words?', True, 'Dimension of capitalization features:', 1, 'F1 score:', (63.07,))

# %%
sentence_tagger.tag('models/tag_scheme=iob,lower=True,zeros=True,char_dim=25,char_lstm_dim=34,char_bidirect=True,word_dim=100,word_lstm_dim=200,word_bidirect=True,pre_emb=glove_s100.txt,all_emb=True,cap_dim=1,crf=True,dropout=0.5,lr_method=sgd-lr_.005',
                    'Este trabalho avalia o uso de Algoritmos Geneticos, pelo aluno Pedro Vitor Quinta de Castro, da Universidade Federal de Goias')
# Out:
# Loading model...
# Compiling...
# Tagging...
# ---- sentence tagged in 0.0068s ----
# u'Este__O trabalho__O avalia__O o__O uso__O de__O Algoritmos__B-PESSOA Geneticos,__I-PESSOA pelo__O aluno__O Pedro__B-PESSOA Vitor__I-PESSOA Quinta__I-PESSOA de__I-PESSOA Castro,__I-PESSOA da__I-PESSOA Universidade__I-PESSOA Federal__I-PESSOA de__O Goias__B-LOCAL\n'
