# %%
import numpy as np
import pandas as pd
import random

from deap import base, creator, tools, algorithms
from scipy.stats import bernoulli
from bitstring import BitArray

import parameters
import ner
# Out:
# Using cuDNN version 6021 on context None
# Mapped name None to device cuda: GeForce GTX 1070 (0000:01:00.0)

# %%
def replace(individual, indexes, value):
    binary_format = '{0:0' + str(indexes[1] - indexes[0])  + 'b}'
    binary_value = binary_format.format(value)
    index_list = list(range(*indexes))
    assert len(index_list) == len(binary_value), 'Binary representation must be the same size as the indexes interval'
    for (index, replacement) in zip(index_list, binary_value):
        individual[index] = int(replacement)
    return individual

# %%
def check_and_replace_if_needed(individual, indexes, min_value, max_value):
    value_bits = BitArray(individual[slice(*indexes)])
    int_value = value_bits.uint
    if int_value < min_value:
        print('adjusting individual to lower bound, switching', int_value, 'at position', indexes, 'for', min_value)
        return replace(indexes=indexes, individual=individual, value=min_value)
    elif int_value > max_value:
        print('adjusting individual to upper bound, switching', int_value, 'at position', indexes, 'for', max_value)
        return replace(indexes=indexes, individual=individual, value=max_value)
    else:
        return individual

# %%
def adjust_individual(individual, min_char_lstm_dim=10, max_char_lstm_dim=50, min_word_lstm_dim=50, max_word_lstm_dim=200):
    individual = check_and_replace_if_needed(individual=individual, 
                                             indexes=(2,8), 
                                             min_value=min_char_lstm_dim, 
                                             max_value=max_char_lstm_dim)
    individual = check_and_replace_if_needed(individual=individual, 
                                             indexes=(9,17), 
                                             min_value=min_word_lstm_dim, 
                                             max_value=max_word_lstm_dim)
    return individual

# %%
def check_individual():
    def decorator(func):
        def wrapper(*args, **kargs):
            individual = func(*args, **kargs)
            return adjust_individual(individual=individual)
        return wrapper
    return decorator

# %%
def check_mate():
    def decorator(func):
        def wrapper(*args, **kargs):
            children = func(*args, **kargs)
            child1, child2 = children
            child1 = adjust_individual(child1)
            child2 = adjust_individual(child2)
            return (child1, child2)
        return wrapper
    return decorator

# %%
def check_mutation():
    def decorator(func):
        def wrapper(*args, **kargs):
            mutant = func(*args, **kargs)
            mutant = adjust_individual(mutant[0])
            return mutant
        return wrapper
    return decorator

# %%
def train_evaluate(ga_individual_solution):
    training_parameters = parameters.get_parameters_from_individual(ga_individual_solution=ga_individual_solution, 
                                                                    train='dataset/train.txt', 
                                                                    dev='dataset/dev.txt', 
                                                                    test='dataset/test.txt', 
                                                                    tag_scheme='iob', 
                                                                    char_dim=25, 
                                                                    word_dim=100, 
                                                                    pre_emb=None, 
                                                                    all_emb=False, 
                                                                    crf=True, 
                                                                    dropout=0.5, 
                                                                    lr_method='sgd-lr_.005',
                                                                    reload=False)
    print('Lower text?', training_parameters['lower'], 
          'Replace digits with zero?', training_parameters['zeros'], 
          'Dimension of LSTM for chars:', training_parameters['char_lstm_dim'],
          'Use bidirectional LSTM for chars?', training_parameters['char_bidirect'],
          'Dimension of LSTM for words:', training_parameters['word_lstm_dim'],
          'Use bidirectional LSTM for words?', training_parameters['word_bidirect'],
          'Dimension of capitalization features:', training_parameters['cap_dim'])
    model = ner.NER(parameters=training_parameters)
    f1_score = model.train(n_epochs=5, verbose=False)
    return f1_score,

# %%
population_size = 4
num_generations = 4
gene_length = 19

# %%
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
toolbox.register('binary', bernoulli.rvs, 0.5)
toolbox.register('individual', tools.initRepeat, creator.Individual, toolbox.binary, n = gene_length)
toolbox.decorate('individual', check_individual())
toolbox.register('population', tools.initRepeat, list , toolbox.individual)

toolbox.register('mate', tools.cxOrdered)
toolbox.decorate('mate', check_mate())
toolbox.register('mutate', tools.mutShuffleIndexes, indpb = 0.6)
toolbox.decorate('mutate', check_mutation())
toolbox.register('select', tools.selTournament, tournsize=2)
toolbox.register('evaluate', train_evaluate)

# %%
population = toolbox.population(n = population_size)
r = algorithms.eaSimple(population, toolbox, cxpb = 0.4, mutpb = 0.1, ngen = num_generations, verbose = False)
# Out:
# ('adjusting individual to upper bound, switching', 63, 'at position', (2, 8), 'for', 50)
# ('adjusting individual to upper bound, switching', 57, 'at position', (2, 8), 'for', 50)
# ('adjusting individual to upper bound, switching', 229, 'at position', (9, 17), 'for', 200)
# ('Lower text?', True, 'Replace digits with zero?', False, 'Dimension of LSTM for chars:', 38, 'Use bidirectional LSTM for chars?', True, 'Dimension of LSTM for words:', 130, 'Use bidirectional LSTM for words?', False, 'Dimension of capitalization features:', 0)
# Model location: ./models/tag_scheme=iob,lower=True,zeros=False,char_dim=25,char_lstm_dim=38,char_bidirect=True,word_dim=100,word_lstm_dim=130,word_bidirect=False,pre_emb=None,all_emb=False,cap_dim=0,crf=True,dropout=0.5,lr_method=sgd-lr_.005
# Found 12769 unique words (62480 in total)
# Found 123 unique characters
# Found 21 unique named entity tags
# 2955 / 529 / 854 sentences in train / dev / test.
# Saving the mappings to disk...
# Compiling...
# ('Starting epoch 0 at...', 'Thu Jan 25 16:37:04 2018')
# processed 8831 tokens with 709 phrases; found: 0 phrases; correct: 0.
# accuracy:  84.58%; precision:   0.00%; recall:   0.00%; FB1:   0.00
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7469/8831 (84.57706%)
# Score on dev: 0.00000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 0 phrases; correct: 0.
# accuracy:  84.58%; precision:   0.00%; recall:   0.00%; FB1:   0.00
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7469/8831 (84.57706%)
# Score on dev: 0.00000
# Epoch 0 done. Average cost: 16.439487
# ('Starting epoch 1 at...', 'Thu Jan 25 16:37:56 2018')
# processed 8831 tokens with 709 phrases; found: 0 phrases; correct: 0.
# accuracy:  84.58%; precision:   0.00%; recall:   0.00%; FB1:   0.00
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7469/8831 (84.57706%)
# Score on dev: 0.00000
# processed 8831 tokens with 709 phrases; found: 0 phrases; correct: 0.
# accuracy:  84.58%; precision:   0.00%; recall:   0.00%; FB1:   0.00
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7469/8831 (84.57706%)
# Score on dev: 0.00000
# processed 8831 tokens with 709 phrases; found: 308 phrases; correct: 115.
# accuracy:  86.64%; precision:  37.34%; recall:  16.22%; FB1:  22.62
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  27.03%; recall:  21.74%; FB1:  24.10  111
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  37.74%; recall:  57.97%; FB1:  45.71  212
#              OBRA: precision:  18.52%; recall:   9.62%; FB1:  12.66  27
#       ORGANIZACAO: precision:  34.62%; recall:  22.50%; FB1:  27.27  26
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  46.90%; recall:  58.17%; FB1:  51.93  258
#             TEMPO: precision:  56.00%; recall:  11.48%; FB1:  19.05  25
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  2
# 7844/8831 (88.82346%)
# Score on dev: 36.38000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 656 phrases; correct: 260.
# accuracy:  89.23%; precision:  39.63%; recall:  36.67%; FB1:  38.10
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  34.94%; recall:  68.12%; FB1:  46.19  269
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  3
#       ORGANIZACAO: precision:  29.63%; recall:  20.00%; FB1:  23.88  27
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  46.69%; recall:  54.33%; FB1:  50.22  242
#             TEMPO: precision:  39.13%; recall:  36.89%; FB1:  37.97  115
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7880/8831 (89.23112%)
# Score on dev: 38.10000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 605 phrases; correct: 268.
# accuracy:  89.97%; precision:  44.30%; recall:  37.80%; FB1:  40.79
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  45.27%; recall:  48.55%; FB1:  46.85  148
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  1
#       ORGANIZACAO: precision:  37.04%; recall:  25.00%; FB1:  29.85  27
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  42.31%; recall:  68.75%; FB1:  52.38  338
#             TEMPO: precision:  55.56%; recall:  36.89%; FB1:  44.33  81
#             VALOR: precision:  30.00%; recall:   7.32%; FB1:  11.76  10
# 7945/8831 (89.96716%)
# Score on dev: 40.79000
# New best score on dev.
# Saving model to disk...
# Epoch 4 done. Average cost: 5.501500
# ('Lower text?', False, 'Replace digits with zero?', False, 'Dimension of LSTM for chars:', 50, 'Use bidirectional LSTM for chars?', True, 'Dimension of LSTM for words:', 139, 'Use bidirectional LSTM for words?', True, 'Dimension of capitalization features:', 0)
# Model location: ./models/tag_scheme=iob,lower=False,zeros=False,char_dim=25,char_lstm_dim=50,char_bidirect=True,word_dim=100,word_lstm_dim=139,word_bidirect=True,pre_emb=None,all_emb=False,cap_dim=0,crf=True,dropout=0.5,lr_method=sgd-lr_.005
# Found 14025 unique words (62480 in total)
# Found 123 unique characters
# Found 21 unique named entity tags
# 2955 / 529 / 854 sentences in train / dev / test.
# Saving the mappings to disk...
# Compiling...
# ('Starting epoch 0 at...', 'Thu Jan 25 16:42:02 2018')
# processed 8831 tokens with 709 phrases; found: 0 phrases; correct: 0.
# accuracy:  84.58%; precision:   0.00%; recall:   0.00%; FB1:   0.00
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7469/8831 (84.57706%)
# Score on dev: 0.00000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 0 phrases; correct: 0.
# accuracy:  84.58%; precision:   0.00%; recall:   0.00%; FB1:   0.00
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7469/8831 (84.57706%)
# Score on dev: 0.00000
# Epoch 0 done. Average cost: 16.271173
# ('Starting epoch 1 at...', 'Thu Jan 25 16:43:12 2018')
# processed 8831 tokens with 709 phrases; found: 0 phrases; correct: 0.
# accuracy:  84.58%; precision:   0.00%; recall:   0.00%; FB1:   0.00
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  38.76%; recall:  81.25%; FB1:  52.48  436
#             TEMPO: precision:  53.09%; recall:  35.25%; FB1:  42.36  81
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7909/8831 (89.55951%)
# Score on dev: 39.25000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 584 phrases; correct: 245.
# accuracy:  89.47%; precision:  41.95%; recall:  34.56%; FB1:  37.90
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  34.43%; recall:  60.87%; FB1:  43.98  244
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  6
#       ORGANIZACAO: precision:  30.30%; recall:  25.00%; FB1:  27.40  33
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  45.31%; recall:  53.37%; FB1:  49.01  245
#             TEMPO: precision:  71.43%; recall:  32.79%; FB1:  44.94  56
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7901/8831 (89.46892%)
# Score on dev: 37.90000
# Epoch 3 done. Average cost: 5.737442
# ('Starting epoch 4 at...', 'Thu Jan 25 16:46:51 2018')
# processed 8831 tokens with 709 phrases; found: 614 phrases; correct: 269.
# accuracy:  89.64%; precision:  43.81%; recall:  37.94%; FB1:  40.67
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  48.60%; recall:  37.68%; FB1:  42.45  107
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  2
#       ORGANIZACAO: precision:  24.56%; recall:  35.00%; FB1:  28.87  57
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  45.21%; recall:  72.60%; FB1:  55.72  334
#             TEMPO: precision:  45.13%; recall:  41.80%; FB1:  43.40  113
#             VALOR: precision: 100.00%; recall:   2.44%; FB1:   4.76  1
# 7916/8831 (89.63877%)
# Score on dev: 40.67000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 670 phrases; correct: 275.
# accuracy:  89.28%; precision:  41.04%; recall:  38.79%; FB1:  39.88
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  41.14%; recall:  47.10%; FB1:  43.92  158
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  2
#       ORGANIZACAO: precision:  18.67%; recall:  35.00%; FB1:  24.35  75
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  46.62%; recall:  66.35%; FB1:  54.76  296
#             TEMPO: precision:  41.91%; recall:  46.72%; FB1:  44.19  136
#             VALOR: precision:  33.33%; recall:   2.44%; FB1:   4.55  3
# 7884/8831 (89.27641%)
# Score on dev: 39.88000
# processed 8831 tokens with 709 phrases; found: 662 phrases; correct: 293.
# accuracy:  89.85%; precision:  44.26%; recall:  41.33%; FB1:  42.74
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  47.06%; recall:  46.38%; FB1:  46.72  136
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  7
#       ORGANIZACAO: precision:  35.29%; recall:  30.00%; FB1:  32.43  34
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  43.27%; recall:  72.60%; FB1:  54.22  349
#             TEMPO: precision:  48.15%; recall:  53.28%; FB1:  50.58  135
#             VALOR: precision: 100.00%; recall:   2.44%; FB1:   4.76  1
# 7935/8831 (89.85392%)
# Score on dev: 42.74000
# New best score on dev.
# Saving model to disk...
# Epoch 4 done. Average cost: 4.989447
# ('Lower text?', False, 'Replace digits with zero?', True, 'Dimension of LSTM for chars:', 22, 'Use bidirectional LSTM for chars?', False, 'Dimension of LSTM for words:', 100, 'Use bidirectional LSTM for words?', True, 'Dimension of capitalization features:', 1)
# Model location: ./models/tag_scheme=iob,lower=False,zeros=True,char_dim=25,char_lstm_dim=22,char_bidirect=False,word_dim=100,word_lstm_dim=100,word_bidirect=True,pre_emb=None,all_emb=False,cap_dim=1,crf=True,dropout=0.5,lr_method=sgd-lr_.005
# Found 13639 unique words (62480 in total)
# Found 114 unique characters
# Found 21 unique named entity tags
# 2955 / 529 / 854 sentences in train / dev / test.
# Saving the mappings to disk...
# Compiling...
# ('Starting epoch 0 at...', 'Thu Jan 25 16:48:29 2018')
# processed 8831 tokens with 709 phrases; found: 33 phrases; correct: 10.
# accuracy:  84.79%; precision:  30.30%; recall:   1.41%; FB1:   2.70
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  41.87%; recall:  58.17%; FB1:  48.69  289
#             TEMPO: precision:  44.90%; recall:  36.07%; FB1:  40.00  98
#             VALOR: precision:  50.00%; recall:   4.88%; FB1:   8.89  4
# 7868/8831 (89.09523%)
# Score on dev: 37.49000
# New best score on dev.
# Saving model to disk...
# Epoch 2 done. Average cost: 6.860830
# ('Starting epoch 3 at...', 'Thu Jan 25 16:51:29 2018')
# processed 8831 tokens with 709 phrases; found: 404 phrases; correct: 192.
# accuracy:  88.50%; precision:  47.52%; recall:  27.08%; FB1:  34.50
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  46.90%; recall:  49.28%; FB1:  48.06  145
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  47.44%; recall:  35.58%; FB1:  40.66  156
#             TEMPO: precision:  48.54%; recall:  40.98%; FB1:  44.44  103
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7815/8831 (88.49507%)
# Score on dev: 34.50000
# processed 8831 tokens with 709 phrases; found: 245 phrases; correct: 115.
# accuracy:  87.26%; precision:  46.94%; recall:  16.22%; FB1:  24.11
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  1
#             LOCAL: precision:  67.65%; recall:  16.67%; FB1:  26.74  34
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   9.52%; recall:   5.00%; FB1:   6.56  21
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  41.53%; recall:  23.56%; FB1:  30.06  118
#             TEMPO: precision:  57.58%; recall:  31.15%; FB1:  40.43  66
#             VALOR: precision:  60.00%; recall:   7.32%; FB1:  13.04  5
# 7706/8831 (87.26079%)
# Score on dev: 24.11000
# processed 8831 tokens with 709 phrases; found: 534 phrases; correct: 237.
# accuracy:  89.53%; precision:  44.38%; recall:  33.43%; FB1:  38.13
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  55.56%; recall:  32.61%; FB1:  41.10  81
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  6
#       ORGANIZACAO: precision:  50.00%; recall:   5.00%; FB1:   9.09  4
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  37.57%; recall:  62.50%; FB1:  46.93  346
#             TEMPO: precision:  61.45%; recall:  41.80%; FB1:  49.76  83
#             VALOR: precision:  64.29%; recall:  21.95%; FB1:  32.73  14
# 7906/8831 (89.52554%)
# Score on dev: 38.13000
# New best score on dev.
# Saving model to disk...
# Epoch 3 done. Average cost: 5.368692
# ('Starting epoch 4 at...', 'Thu Jan 25 16:52:30 2018')
# processed 8831 tokens with 709 phrases; found: 651 phrases; correct: 291.
# accuracy:  90.35%; precision:  44.70%; recall:  41.04%; FB1:  42.79
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  1
#             LOCAL: precision:  38.49%; recall:  66.67%; FB1:  48.81  239
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  1
#       ORGANIZACAO: precision:  42.86%; recall:   7.50%; FB1:  12.77  7
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  44.52%; recall:  62.50%; FB1:  52.00  292
#             TEMPO: precision:  63.64%; recall:  40.16%; FB1:  49.25  77
#             VALOR: precision:  50.00%; recall:  41.46%; FB1:  45.33  34
# 7979/8831 (90.35217%)
# Score on dev: 42.79000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 637 phrases; correct: 285.
# accuracy:  90.00%; precision:  44.74%; recall:  40.20%; FB1:  42.35
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  51.52%; recall:  36.96%; FB1:  43.04  99
#              OBRA: precision:   4.35%; recall:   1.92%; FB1:   2.67  23
#       ORGANIZACAO: precision:  28.57%; recall:  25.00%; FB1:  26.67  35
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  43.66%; recall:  74.52%; FB1:  55.06  355
#             TEMPO: precision:  57.47%; recall:  40.98%; FB1:  47.85  87
#             VALOR: precision:  47.37%; recall:  43.90%; FB1:  45.57  38
# 7948/8831 (90.00113%)
# Score on dev: 42.35000
# processed 8831 tokens with 709 phrases; found: 591 phrases; correct: 264.
# accuracy:  90.19%; precision:  44.67%; recall:  37.24%; FB1:  40.62
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  1
#             LOCAL: precision:  47.22%; recall:  36.96%; FB1:  41.46  108
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  5
#       ORGANIZACAO: precision:  19.12%; recall:  32.50%; FB1:  24.07  68
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  44.74%; recall:  65.38%; FB1:  53.12  304
#             TEMPO: precision:  62.22%; recall:  45.90%; FB1:  52.83  90
#             VALOR: precision:  53.33%; recall:  19.51%; FB1:  28.57  15
# 7965/8831 (90.19364%)
# Score on dev: 40.62000
# Epoch 4 done. Average cost: 4.773287
# ('Lower text?', True, 'Replace digits with zero?', False, 'Dimension of LSTM for chars:', 50, 'Use bidirectional LSTM for chars?', True, 'Dimension of LSTM for words:', 200, 'Use bidirectional LSTM for words?', False, 'Dimension of capitalization features:', 1)
# Model location: ./models/tag_scheme=iob,lower=True,zeros=False,char_dim=25,char_lstm_dim=50,char_bidirect=True,word_dim=100,word_lstm_dim=200,word_bidirect=False,pre_emb=None,all_emb=False,cap_dim=1,crf=True,dropout=0.5,lr_method=sgd-lr_.005
# Found 12769 unique words (62480 in total)
# Found 123 unique characters
# Found 21 unique named entity tags
# 2955 / 529 / 854 sentences in train / dev / test.
# Saving the mappings to disk...
# Compiling...
# ('Starting epoch 0 at...', 'Thu Jan 25 16:53:54 2018')
# processed 8831 tokens with 709 phrases; found: 0 phrases; correct: 0.
# accuracy:  84.58%; precision:   0.00%; recall:   0.00%; FB1:   0.00
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7469/8831 (84.57706%)
# Score on dev: 0.00000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 2 phrases; correct: 0.
# accuracy:  84.58%; precision:   0.00%; recall:   0.00%; FB1:   0.00
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:   0.00%; recall:   0.00%; FB1:   0.00  2
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7469/8831 (84.57706%)
# Score on dev: 0.00000
# Epoch 0 done. Average cost: 14.893203
# ('Starting epoch 1 at...', 'Thu Jan 25 16:54:48 2018')
# processed 8831 tokens with 709 phrases; found: 0 phrases; correct: 0.
# accuracy:  84.58%; precision:   0.00%; recall:   0.00%; FB1:   0.00
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7469/8831 (84.57706%)
# Score on dev: 0.00000
# processed 8831 tokens with 709 phrases; found: 147 phrases; correct: 72.
# accuracy:  86.16%; precision:  48.98%; recall:  10.16%; FB1:  16.82
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:   0.00%; recall:   0.00%; FB1:   0.00  1
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  49.32%; recall:  34.62%; FB1:  40.68  146
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7609/8831 (86.16238%)
# Score on dev: 16.82000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 406 phrases; correct: 145.
# accuracy:  87.05%; precision:  35.71%; recall:  20.45%; FB1:  26.01
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  40.91%; recall:  13.04%; FB1:  19.78  44
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  35.18%; recall:  61.06%; FB1:  44.64  361
#             TEMPO: precision:   0.00%; recall:   0.00%; FB1:   0.00  1
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7687/8831 (87.04563%)
# Score on dev: 26.01000
# New best score on dev.
# Saving model to disk...
# Epoch 1 done. Average cost: 9.911671
# ('Starting epoch 2 at...', 'Thu Jan 25 16:55:44 2018')
# processed 8831 tokens with 709 phrases; found: 566 phrases; correct: 171.
# accuracy:  87.43%; precision:  30.21%; recall:  24.12%; FB1:  26.82
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  23.36%; recall:  64.49%; FB1:  34.30  381
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  4
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  46.47%; recall:  37.98%; FB1:  41.80  170
#             TEMPO: precision:  27.27%; recall:   2.46%; FB1:   4.51  11
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7721/8831 (87.43064%)
# Score on dev: 26.82000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 594 phrases; correct: 215.
# accuracy:  88.05%; precision:  36.20%; recall:  30.32%; FB1:  33.00
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  35.24%; recall:  53.62%; FB1:  42.53  210
#              OBRA: precision:   5.88%; recall:   1.92%; FB1:   2.90  17
#       ORGANIZACAO: precision:  27.78%; recall:  12.50%; FB1:  17.24  18
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  39.76%; recall:  62.50%; FB1:  48.60  327
#             TEMPO: precision:  22.73%; recall:   4.10%; FB1:   6.94  22
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7776/8831 (88.05345%)
# Score on dev: 33.00000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 633 phrases; correct: 228.
# accuracy:  88.33%; precision:  36.02%; recall:  32.16%; FB1:  33.98
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  31.62%; recall:  66.67%; FB1:  42.89  291
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  4
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  40.41%; recall:  56.73%; FB1:  47.20  292
#             TEMPO: precision:  39.13%; recall:  14.75%; FB1:  21.43  46
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7800/8831 (88.32522%)
# Score on dev: 33.98000
# New best score on dev.
# Saving model to disk...
# Epoch 2 done. Average cost: 7.126061
# ('Starting epoch 3 at...', 'Thu Jan 25 16:56:40 2018')
# processed 8831 tokens with 709 phrases; found: 625 phrases; correct: 229.
# accuracy:  88.02%; precision:  36.64%; recall:  32.30%; FB1:  34.33
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  43.45%; recall:  45.65%; FB1:  44.52  145
#              OBRA: precision:   7.14%; recall:   3.85%; FB1:   5.00  28
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  38.40%; recall:  66.83%; FB1:  48.77  362
#             TEMPO: precision:  27.78%; recall:  20.49%; FB1:  23.58  90
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7773/8831 (88.01948%)
# Score on dev: 34.33000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 631 phrases; correct: 238.
# accuracy:  88.40%; precision:  37.72%; recall:  33.57%; FB1:  35.52
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  39.66%; recall:  51.45%; FB1:  44.79  179
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  1
#       ORGANIZACAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  35.73%; recall:  66.83%; FB1:  46.57  389
#             TEMPO: precision:  45.16%; recall:  22.95%; FB1:  30.43  62
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7807/8831 (88.40448%)
# Score on dev: 35.52000
# New best score on dev.
# Saving model to disk...
# processed 8831 tokens with 709 phrases; found: 625 phrases; correct: 256.
# accuracy:  88.88%; precision:  40.96%; recall:  36.11%; FB1:  38.38
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  43.40%; recall:  50.00%; FB1:  46.46  159
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  3
#       ORGANIZACAO: precision:  29.41%; recall:  25.00%; FB1:  27.03  34
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  40.74%; recall:  74.04%; FB1:  52.56  378
#             TEMPO: precision:  47.92%; recall:  18.85%; FB1:  27.06  48
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  3
# 7849/8831 (88.88008%)
# Score on dev: 38.38000
# New best score on dev.
# Saving model to disk...
# Epoch 3 done. Average cost: 6.110808
# ('Starting epoch 4 at...', 'Thu Jan 25 16:57:36 2018')
# processed 8831 tokens with 709 phrases; found: 611 phrases; correct: 245.
# accuracy:  88.82%; precision:  40.10%; recall:  34.56%; FB1:  37.12
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  1
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  1
#             LOCAL: precision:  44.51%; recall:  55.80%; FB1:  49.52  173
#              OBRA: precision:  10.00%; recall:   7.69%; FB1:   8.70  40
#       ORGANIZACAO: precision:  20.34%; recall:  30.00%; FB1:  24.24  59
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  48.29%; recall:  54.33%; FB1:  51.13  234
#             TEMPO: precision:  37.86%; recall:  31.97%; FB1:  34.67  103
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
# 7844/8831 (88.82346%)
# Score on dev: 37.12000
# processed 8831 tokens with 709 phrases; found: 605 phrases; correct: 260.
# accuracy:  89.14%; precision:  42.98%; recall:  36.67%; FB1:  39.57
#        ABSTRACCAO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#     ACONTECIMENTO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             COISA: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#             LOCAL: precision:  55.34%; recall:  41.30%; FB1:  47.30  103
#              OBRA: precision:   0.00%; recall:   0.00%; FB1:   0.00  2
#       ORGANIZACAO: precision:  35.48%; recall:  27.50%; FB1:  30.99  31
#             OUTRO: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#            PESSOA: precision:  37.56%; recall:  71.15%; FB1:  49.17  394
#             TEMPO: precision:  60.27%; recall:  36.07%; FB1:  45.13  73
#             VALOR: precision:   0.00%; recall:   0.00%; FB1:   0.00  2
# 7872/8831 (89.14053%)
# Score on dev: 39.57000
# New best score on dev.
# Saving model to disk...

# %%
best_individuals = tools.selBest(population,k = 1)

lower = None
zeros = None
char_lstm_dim = None
char_bidirect = None
word_lstm_dim = None
word_bidirect = None
cap_dim = None

for bi in best_individuals:
    lower_bit = bi[0]
    zeros_bit = bi[1]
    char_lstm_dim_bits = BitArray(bi[2:8])
    char_bidirect_bit = bi[8]
    word_lstm_dim_bits = BitArray(bi[9:17])
    word_bidirect_bit = bi[17]
    cap_dim_bit = bi[18]
    
    lower = lower_bit == 1
    zeros = zeros_bit == 1
    char_lstm_dim = char_lstm_dim_bits.uint
    char_bidirect = char_bidirect_bit == 1
    word_lstm_dim = word_lstm_dim_bits.uint
    word_bidirect = word_bidirect_bit == 1
    cap_dim = cap_dim_bit
    
    print('Lower text?', lower, 
          'Replace digits with zero?', zeros, 
          'Dimension of LSTM for chars:', char_lstm_dim,
          'Use bidirectional LSTM for chars?', char_bidirect,
          'Dimension of LSTM for words:', word_lstm_dim,
          'Use bidirectional LSTM for words?', word_bidirect,
          'Dimension of capitalization features:', cap_dim,
          'F1 score:', bi.fitness.values)

# %%
toolbox.select(population, len(population))

# %%
population = toolbox.population(n=5)
print(type(population), population)

# %%
children = toolbox.mate(population[0], population[1])

# %%
child1, child2 = children

# %%
mutant = toolbox.mutate(child1)

# %%
print(mutant)
toolbox.evaluate(mutant)

# %%
mutant1 = mutant[0]

# %%
print(type(mutant), type(mutant1))
print(mutant1)

# %%
print(child1)

# %%
print(mutant)

# %%
toolbox.select(population)
